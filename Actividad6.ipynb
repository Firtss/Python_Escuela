# %% [markdown]
# <a href="https://colab.research.google.com/github/Firtss/Python_Escuela/blob/main/Actividad6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ACTIVIDAD 6
# (ciclos y funciones)

# %% [markdown]
# 1.- FUNCIÓN QUE LEA n CANTIDAD DE NÚMEROS HASTA QUE EL USUARIO LO DESEE, DESPLEGAR LA SUMA DE LOS NÚMEROS, MEDIA Y VALOR DE LOS NÚMEROS MAYORES Y MENORES.
#
# 2.- FUNCIÓN QUE GENERE 15 NÚMEROS IMPARES ENTRE 10 Y 60 o MÁXIMO DE 25 NÚMEROS. DESPLEGAR LA MEDIA DE LOS PARES Y MEDIA DE IMPARES.
#
# 3.- FUNCIÓN QUE SIRVA PARA LEER UN RANGO DADO POR EL USUARIO. REPETIR ESTA ACCIÓN HASTA QUE EL USUARIO LO DESEE, DESPLEGAR CANTIDAD DE NUMEROS Y PROMEDIO DE LOS NUMEROS..
#
# 4.- FUNCIÓN QUE RECIBA COMO PARÁMETRO LOS VALORES PARA EL ÁREA DE UN TRIANGULO Y RETORNE SU RESULTADO
#
# 5.- FUNCION QUE SIRVA QUE SIRVA PARA EVALUAR EL PROMEDIO DE 3 CALIFICACIONES DADAS, SI EL USUARIO SU CALIFICACION ES APROBADA MANDAR MSGE QUE DIGA "felicidades avanzas al siguiente semestre", SI LA CALIFICACIONE ESTA REPROBADA EL MENSAGE "repetir materia " EL ALUMNO TENDRA UN MAXIMO DE CURSAR 3 VESES LA MATERIA, SI LA REPRUEBA 3 VESES MANDAR MSGE " lastima estas fuera de la UABC"

# %%
from IPython.display import clear_output
from random import randint
def mostrar_menu(opciones):
    print('Seleccione una opción:')
    for clave in sorted(opciones):
        print(f' {clave}) {opciones[clave][0]}')


def leer_opcion(opciones):
    while (a := input('Opción: ')) not in opciones:
        print('Opción incorrecta, vuelva a intentarlo.')
    return a


def ejecutar_opcion(opcion, opciones):
    opciones[opcion][1]()


def generar_menu(opciones, opcion_salida):
    opcion = None
    while opcion != opcion_salida:
        mostrar_menu(opciones)
        opcion = leer_opcion(opciones)
        ejecutar_opcion(opcion, opciones)
        print()


def menu_principal():
    opciones = {
        '1': ('Suma, media, mayores y menores',suma),
        '2': ('Pares e impares',pares_impares),
        '3': ('Rango dado por el usuario',rango),
        '4': ('Area de un triangulo',triangulo),
        '5': ('Promedio de 3 calificaciones',promedio),
        '6': ('Salir',salir)
    }

    generar_menu(opciones, '6')


def suma():
    print('Has elegido la opción 1\n')
    num = 1
    cont = 0
    sum = 0
    mayor = 0
    menor = 0
    try:
        while num != 0:
            num = int(input("Dame numeors enteros.\nPara salir precione 0\n"))
            cont = cont + 1
            sum = sum + num
            if num > mayor:
                mayor = num
            else:
                menor = num
    except:
        print("Te pedi un numero, intentalo de nuevo")
    else:
        media = sum / cont
        print(f"La suma de los numeros es de: {sum}")
        print(f"La media de los numeros es de: {media}")
        print(f"El numero mayor es: {mayor}")
        print(f"El numero menor es: {menor}")


def pares_impares():
    print('Has elegido la opción 2\n')
    from random import randrange
    par = 0
    impar = 0
    cont_impar = 0
    cont_par = 0
    try:
        for i in range(15):
            num = randrange(10,60,3)
            print(num)
            if num %2 == 0:
                par = par + num
                cont_par = cont_par + 1
            else:
                impar = impar + num
                cont_impar = cont_impar + 1
    except:
        print("Hay un promebla con el codigo")
    else:
        media_par = par / cont_par
        media_impar = impar / cont_impar
        print(f"La media de par es: {media_par}\nLa media de impar es: {media_impar}")

def rango():
    print('Has elegido la opción 3\n')
    total = 0
    prom = 0
    sum = 0
    num = 1
    cont = 0
    band = 0
    try:
        print("De donde hasta donde quieres tu rango?\n")
        rango1 = int(input("rango 1\n"))
        rango2 = int(input("rango 2\n"))
        for i in range(rango1,rango2):
            while num != 0 and band != 1:
                num = int(input("Dame un numeros entero positivo de tu rango\nSi desear salir pon un 0\n"))
                sum = sum + num
                cont = cont + 1
                if num == "0":
                    band = 1
                elif num < rango1 or num > rango2:
                    print("Tu numero excedio de tu rango")
                    break
    except:
        print("Te pedi un numero, intentalo de nuevo")
    else:
        prom = sum / cont
        print(f"El total de numeros es de: {cont}")
        print(f"La suma total de los numeros es de: {prom}")

def triangulo():
    print('Has elegido la opción 3\n')
    try:
        print("Dame los valores b de base y h de altura para sacar el area del triangulo\n")
        b = int(input("Valor de b: "))
        h = int(input("Valor de h: "))
    except:
        print("Te pedi numero, no letras.\nIntentalo de nuevo")
    else:
        area = (b * h)/2
        print(f"El area del triangulo es: {area}")

def promedio():
    print('Has elegido la opción 3\n')
    repro = 0
    apro = 0
    try:
        while repro != 3 and apro != 3:
            promedio = int(input("Dame tu promedio de la materia\t"))
            if promedio <60:
                repro = repro + 1
                print(f"Reprobaste por {repro} vez")
                if repro == 3:
                     print("Ya valiste, ya reprobaste 3 veces")
                else:
                    print("Aun te quedan oportunidades")
            else:
                apro = apro + 1
                print("Aprobaste!!, Felicidades por no aprobar!!")
    except TypeError:
         print("No me extra;aria si reprobaras, te pedi tu calificacion")
    except:
          print("Hay un error en el codigo")

def salir():
    print('Saliendo\n')


if __name__ == '__main__':
    menu_principal()
# Out:
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 3
# Has elegido la opción 3
#
# De donde hasta donde quieres tu rango?
#
# rango 1
# 10
# rango 2
# 20
# Dame un numeros entero positivo de tu rango
# Si desear salir pon un 0
# 10
# Dame un numeros entero positivo de tu rango
# Si desear salir pon un 0
# 15
# Dame un numeros entero positivo de tu rango
# Si desear salir pon un 0
# 20
# Dame un numeros entero positivo de tu rango
# Si desear salir pon un 0
# 0
# Tu numero excedio de tu rango
# El total de numeros es de: 4
# La suma total de los numeros es de: 11.25
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 4
# Has elegido la opción 3
#
# Dame los valores b de base y h de altura para sacar el area del triangulo
#
# Valor de b: 4
# Valor de h: 6
# El area del triangulo es: 12.0
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 5
# Has elegido la opción 3
#
# Dame tu promedio de la materia	80
# Aprobaste!!, Felicidades por no aprobar!!
# Dame tu promedio de la materia	90
# Aprobaste!!, Felicidades por no aprobar!!
# Dame tu promedio de la materia	100
# Aprobaste!!, Felicidades por no aprobar!!
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 1
# Has elegido la opción 1
#
# Dame numeors enteros.
# Para salir precione 0
# 15
# Dame numeors enteros.
# Para salir precione 0
# 20
# Dame numeors enteros.
# Para salir precione 0
# 60
# Dame numeors enteros.
# Para salir precione 0
# 30
# Dame numeors enteros.
# Para salir precione 0
# 0
# La suma de los numeros es de: 125
# La media de los numeros es de: 25.0
# El numero mayor es: 60
# El numero menor es: 0
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 2
# Has elegido la opción 2
#
# 19
# 19
# 10
# 19
# 46
# 52
# 19
# 25
# 16
# 28
# 34
# 25
# 31
# 25
# 49
# La media de par es: 31.0
# La media de impar es: 25.666666666666668
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 2
# Has elegido la opción 2
#
# 37
# 46
# 31
# 37
# 58
# 13
# 34
# 28
# 49
# 52
# 34
# 46
# 43
# 46
# 43
# La media de par es: 43.0
# La media de impar es: 36.142857142857146
#
# Seleccione una opción:
#  1) Suma, media, mayores y menores
#  2) Pares e impares
#  3) Rango dado por el usuario
#  4) Area de un triangulo
#  5) Promedio de 3 calificaciones
#  6) Salir
# Opción: 6
# Saliendo
